# %%
# %load_ext kedro.ipython
# Out:
# [03/21/26 22:17:27] INFO     Registered line magic '%reload_kedro'                                   ]8;id=242937;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=397619;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\ipython\__init__.py#64\64]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=731839;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=267745;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\ipython\__init__.py#66\66]8;;\
# ...

# %%
# !uv pip install --upgrade seaborn matplotlib
# !uv pip install category_encoders

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = catalog.load("domy_small_categories_cleanup")
df = df.sort_index(axis=1)
#  tu bedzie target encoding, wiec musze wziac dane po rozroznieniu ich na test set i train set

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

target_col = 'SalePrice'

X = df.drop(columns=[target_col])
y = df[target_col]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from category_encoders import TargetEncoder
cols_to_encode = ['Exterior1st', 'Exterior2nd', 'Neighborhood']

encoder = TargetEncoder(cols=cols_to_encode)
X_train_encoded = encoder.fit_transform(X_train, y_train)
X_test_encoded = encoder.transform(X_test)

# %%
X_train_encoded['Neighborhood']

# %%
for col in df:
    print(col + ": " + str(df[col].dtype))
