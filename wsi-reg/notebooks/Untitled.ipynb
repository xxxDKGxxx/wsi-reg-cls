# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
# !uv pip install --upgrade seaborn matplotlib
# Out:
# Using Python 3.12.7 environment at: C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv
# Resolved 14 packages in 347ms
# Prepared 5 packages in 13ms
# Uninstalled 5 packages in 999ms
# Installed 5 packages in 1.24s
#  - fonttools==4.61.1
#  + fonttools==4.62.1
#  - kiwisolver==1.4.9
#  + kiwisolver==1.5.0
#  - numpy==2.4.2
#  + numpy==2.4.3
#  - pandas==2.3.3
#  + pandas==3.0.1
#  - seaborn==0.12.2
#  + seaborn==0.13.2

# %%
import pandas as pd

df = catalog.load("domy")

df['LotFrontage'] = pd.to_numeric(df['LotFrontage'], errors='coerce')
df['MasVnrArea'] = pd.to_numeric(df['MasVnrArea'], errors='coerce')
df['GarageYrBlt'] = pd.to_numeric(df['GarageYrBlt'], errors='coerce')

# pd.reset_option('^display.', silent=True)
# # Wyświetlanie wszystkich kolumn
pd.set_option('display.max_columns', None)

# Opcjonalnie: wyświetlanie pełnej zawartości komórek (nie ucina tekstu)
pd.set_option('display.max_colwidth', None)
df
# Out:
# [03/22/26 19:47:28] INFO     Loading data from domy (CSVDataset)...                            ]8;id=337083;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=636851;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave     ?      Reg
# 1        2          20       RL         80.0     9600   Pave     ?      Reg
# 2        3          60       RL         68.0    11250   Pave     ?      IR1
# 3        4          70       RL         60.0     9550   Pave     ?      IR1
# 4        5          60       RL         84.0    14260   Pave     ?      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave     ?      Reg
# 1456  1457          20       RL         85.0    13175   Pave     ?      Reg
# 1457  1458          70       RL         66.0     9042   Pave     ?      Reg
# 1458  1459          20       RL         68.0     9717   Pave     ?      Reg
# 1459  1460          20       RL         75.0     9937   Pave     ?      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg   'Wd Sdng'   'Wd Shng'        NaN
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd        NaN
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd        NaN
# 1458          1996       Hip  CompShg     MetalSd     MetalSd        NaN
# 1459          1965     Gable  CompShg     HdBoard     HdBoard        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0           ?     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0           ?     Attchd       1950.0
# 1459             6        Typ           0           ?     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0      ?      ?           ?        0       2    2008       WD
# 1            0      ?      ?           ?        0       5    2007       WD
# 2            0      ?      ?           ?        0       9    2008       WD
# 3            0      ?      ?           ?        0       2    2006       WD
# 4            0      ?      ?           ?        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0      ?      ?           ?        0       8    2007       WD
# 1456         0      ?  MnPrv           ?        0       2    2010       WD
# 1457         0      ?  GdPrv        Shed     2500       5    2010       WD
# 1458         0      ?      ?           ?        0       4    2010       WD
# 1459         0      ?      ?           ?        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 0           Normal     208500
# 1           Normal     181500
# 2           Normal     223500
# 3          Abnorml     140000
# 4           Normal     250000
# ...            ...        ...
# 1455        Normal     175000
# 1456        Normal     210000
# 1457        Normal     266500
# 1458        Normal     142125
# 1459        Normal     147500
#
# [1460 rows x 81 columns]

# %%
treshold = 15
cat_features_s = []
cat_features_b = []
num_features = []

for col in df.columns:
    if (df[col].dtype == 'object' and df[col].nunique() < 10):
        cat_features_s.append(col)
    elif df[col].dtype == 'object' and df[col].nunique() >= 10:
        cat_features_b.append(col)
    else:
        num_features.append(col)

df_cat_s = df[cat_features_s]
df_cat_b = df[cat_features_b]
df_num = df[num_features]

df_cat_s = df_cat_s.fillna('?')
df_cat_s
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave     ?      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave     ?      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave     ?      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave     ?      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave     ?      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave     ?      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave     ?      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave     ?      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave     ?      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave     ?      Reg         Lvl    AllPub    Inside       Gtl
#
#      Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl MasVnrType  \
# 0          Norm       Norm     1Fam     2Story     Gable  CompShg    BrkFace
# 1         Feedr       Norm     1Fam     1Story     Gable  CompShg          ?
# 2          Norm       Norm     1Fam     2Story     Gable  CompShg    BrkFace
# 3          Norm       Norm     1Fam     2Story     Gable  CompShg          ?
# 4          Norm       Norm     1Fam     2Story     Gable  CompShg    BrkFace
# ...         ...        ...      ...        ...       ...      ...        ...
# 1455       Norm       Norm     1Fam     2Story     Gable  CompShg          ?
# 1456       Norm       Norm     1Fam     1Story     Gable  CompShg      Stone
# 1457       Norm       Norm     1Fam     2Story     Gable  CompShg          ?
# 1458       Norm       Norm     1Fam     1Story       Hip  CompShg          ?
# 1459       Norm       Norm     1Fam     1Story     Gable  CompShg          ?
#
#      ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0           Gd        TA      PConc       Gd       TA           No
# 1           TA        TA     CBlock       Gd       TA           Gd
# 2           Gd        TA      PConc       Gd       TA           Mn
# 3           TA        TA     BrkTil       TA       Gd           No
# 4           Gd        TA      PConc       Gd       TA           Av
# ...        ...       ...        ...      ...      ...          ...
# 1455        TA        TA      PConc       Gd       TA           No
# 1456        TA        TA     CBlock       Gd       TA           No
# 1457        Ex        Gd      Stone       TA       Gd           No
# 1458        TA        TA     CBlock       TA       TA           Mn
# 1459        Gd        TA     CBlock       TA       TA           No
#
#      BsmtFinType1 BsmtFinType2 Heating HeatingQC CentralAir Electrical  \
# 0             GLQ          Unf    GasA        Ex          Y      SBrkr
# 1             ALQ          Unf    GasA        Ex          Y      SBrkr
# 2             GLQ          Unf    GasA        Ex          Y      SBrkr
# 3             ALQ          Unf    GasA        Gd          Y      SBrkr
# 4             GLQ          Unf    GasA        Ex          Y      SBrkr
# ...           ...          ...     ...       ...        ...        ...
# 1455          Unf          Unf    GasA        Ex          Y      SBrkr
# 1456          ALQ          Rec    GasA        TA          Y      SBrkr
# 1457          GLQ          Unf    GasA        Ex          Y      SBrkr
# 1458          GLQ          Rec    GasA        Gd          Y      FuseA
# 1459          BLQ          LwQ    GasA        Gd          Y      SBrkr
#
#      KitchenQual Functional FireplaceQu GarageType GarageFinish GarageQual  \
# 0             Gd        Typ           ?     Attchd          RFn         TA
# 1             TA        Typ          TA     Attchd          RFn         TA
# 2             Gd        Typ          TA     Attchd          RFn         TA
# 3             Gd        Typ          Gd     Detchd          Unf         TA
# 4             Gd        Typ          TA     Attchd          RFn         TA
# ...          ...        ...         ...        ...          ...        ...
# 1455          TA        Typ          TA     Attchd          RFn         TA
# 1456          TA       Min1          TA     Attchd          Unf         TA
# 1457          Gd        Typ          Gd     Attchd          RFn         TA
# 1458          Gd        Typ           ?     Attchd          Unf         TA
# 1459          TA        Typ           ?     Attchd          Fin         TA
#
#      GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition
# 0            TA          Y      ?      ?           ?       WD        Normal
# 1            TA          Y      ?      ?           ?       WD        Normal
# 2            TA          Y      ?      ?           ?       WD        Normal
# 3            TA          Y      ?      ?           ?       WD       Abnorml
# 4            TA          Y      ?      ?           ?       WD        Normal
# ...         ...        ...    ...    ...         ...      ...           ...
# 1455         TA          Y      ?      ?           ?       WD        Normal
# 1456         TA          Y      ?  MnPrv           ?       WD        Normal
# 1457         TA          Y      ?  GdPrv        Shed       WD        Normal
# 1458         TA          Y      ?      ?           ?       WD        Normal
# 1459         TA          Y      ?      ?           ?       WD        Normal
#
# [1460 rows x 40 columns]

# %%
df_cat_b
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      Neighborhood Exterior1st Exterior2nd
# 0         CollgCr     VinylSd     VinylSd
# 1         Veenker     MetalSd     MetalSd
# 2         CollgCr     VinylSd     VinylSd
# 3         Crawfor   'Wd Sdng'   'Wd Shng'
# 4         NoRidge     VinylSd     VinylSd
# ...           ...         ...         ...
# 1455      Gilbert     VinylSd     VinylSd
# 1456       NWAmes     Plywood     Plywood
# 1457      Crawfor     CemntBd     CmentBd
# 1458        NAmes     MetalSd     MetalSd
# 1459      Edwards     HdBoard     HdBoard
#
# [1460 rows x 3 columns]

# %%
df_num
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0          2003          2003       196.0         706           0        150
# 1          1976          1976         0.0         978           0        284
# 2          2001          2002       162.0         486           0        434
# 3          1915          1970         0.0         216           0        540
# 4          2000          2000       350.0         655           0        490
# ...         ...           ...         ...         ...         ...        ...
# 1455       1999          2000         0.0           0           0        953
# 1456       1978          1988       119.0         790         163        589
# 1457       1941          2006         0.0         275           0        877
# 1458       1950          1996         0.0          49        1029          0
# 1459       1965          1965         0.0         830         290        136
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0             856       856       854             0       1710             1
# 1            1262      1262         0             0       1262             0
# 2             920       920       866             0       1786             1
# 3             756       961       756             0       1717             1
# 4            1145      1145      1053             0       2198             1
# ...           ...       ...       ...           ...        ...           ...
# 1455          953       953       694             0       1647             0
# 1456         1542      2073         0             0       2073             1
# 1457         1152      1188      1152             0       2340             0
# 1458         1078      1078         0             0       1078             1
# 1459         1256      1256         0             0       1256             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0                0         2         1             3             1
# 1                1         2         0             3             1
# 2                0         2         1             3             1
# 3                0         1         0             3             1
# 4                0         2         1             4             1
# ...            ...       ...       ...           ...           ...
# 1455             0         2         1             3             1
# 1456             0         2         0             3             1
# 1457             0         2         0             4             1
# 1458             0         1         0             2             1
# 1459             0         1         1             3             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# 0                8           0       2003.0           2         548
# 1                6           1       1976.0           2         460
# 2                6           1       2001.0           2         608
# 3                7           1       1998.0           3         642
# 4                9           1       2000.0           3         836
# ...            ...         ...          ...         ...         ...
# 1455             7           1       1999.0           2         460
# 1456             7           2       1978.0           2         500
# 1457             9           2       1941.0           1         252
# 1458             5           0       1950.0           1         240
# 1459             6           0       1965.0           1         276
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold  SalePrice
# 0            0        0       2    2008     208500
# 1            0        0       5    2007     181500
# 2            0        0       9    2008     223500
# 3            0        0       2    2006     140000
# 4            0        0      12    2008     250000
# ...        ...      ...     ...     ...        ...
# 1455         0        0       8    2007     175000
# 1456         0        0       2    2010     210000
# 1457         0     2500       5    2010     266500
# 1458         0        0       4    2010     142125
# 1459         0        0       6    2008     147500
#
# [1460 rows x 38 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_theme(style="whitegrid")

def plot_distributions(dataframe):
    numeric_cols = dataframe.select_dtypes(include=['number']).columns

    for col in numeric_cols:

        fig = plt.figure(figsize=(15, 8))
        grid = plt.GridSpec(2, 2, height_ratios=(.15, .85), width_ratios=(.7, .3), hspace=0.3, wspace=0.2)

        ax_box = fig.add_subplot(grid[0, 0], sharex=None)
        ax_hist = fig.add_subplot(grid[1, 0], sharex=ax_box)
        ax_qq = fig.add_subplot(grid[:, 1])

        # 1. Boxplot
        sns.boxplot(x=dataframe[col], ax=ax_box, color="skyblue")
        ax_box.set(xlabel='')
        
        # 2. Histplot
        sns.histplot(data=dataframe, x=col, ax=ax_hist, kde=True, bins=30, color="skyblue")
        ax_hist.set(ylabel='Liczba wystąpień (Count)')
        
        # 3. QQ-Plot
        stats.probplot(dataframe[col].dropna(), dist="norm", plot=ax_qq)
        ax_qq.set_title("Normal QQ-Plot")
        
        plt.suptitle(f'Analiza zmiennej: {col}', fontsize=16, fontweight='bold', y=0.98)
        plt.show()

plot_distributions(df_num)
# Out:
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=979991;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=126723;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:29] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=725471;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=994883;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=378113;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=903681;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=659673;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=390702;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:30] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=29854;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=665213;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=422645;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=537376;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=870122;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=522876;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:31] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=162381;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=552104;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=82303;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=304112;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:32] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=906796;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=942300;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=710409;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=987100;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=394758;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=387727;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:33] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=213589;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=347277;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=264897;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=909926;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=626485;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=57609;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:34] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=531464;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=132908;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=374749;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=810568;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=710222;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=263094;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:35] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=448242;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=383749;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=956954;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=194497;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=743030;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=924449;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:36] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=886271;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=978418;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=874;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=467133;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:37] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=99622;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=694872;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=890153;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=184619;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=630644;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=223249;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:38] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=324384;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=330303;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=135096;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=429224;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=391065;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=607204;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:39] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=741927;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=539767;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=369026;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=718908;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=66295;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=257797;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:40] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=182159;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=279432;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=462858;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=241818;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=634944;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=33227;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
# [03/22/26 19:47:41] WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=467456;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=651766;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=272905;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=703440;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>
#                     WARNING  C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\sit ]8;id=931393;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py\warnings.py]8;;\:]8;id=179877;file://C:\Users\arczi\AppData\Local\Programs\Python\Python312\Lib\warnings.py#112\112]8;;\
#                              e-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na
#                              option is deprecated and will be removed in a future version. Convert
#                              inf values to NaN before operating instead.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x800 with 3 Axes>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

print("Seaborn:", sns.__version__)
print("Matplotlib:", matplotlib.__version__)

corr_matrix = df_num.corr(numeric_only=True)

plt.figure(figsize=(20, 20))

sns.heatmap(
    corr_matrix, 
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5
)

plt.title("Macierz Korelacji dla wartości numerycznych", fontsize=16)
plt.show()
# Out:
# Seaborn: 0.12.2
# Matplotlib: 3.10.8
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x2000 with 2 Axes>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

print("Seaborn:", sns.__version__)
print("Matplotlib:", matplotlib.__version__)

corr_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(20, 20))

sns.heatmap(
    corr_matrix, 
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5
)

plt.title("Macierz Korelacji", fontsize=16)
plt.show()
# Out:
# Seaborn: 0.12.2
# Matplotlib: 3.10.8
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x2000 with 2 Axes>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in df_cat_b.columns:
    num_cats = df_cat_b[col].nunique()
    plt.figure(figsize=(12, max(6, num_cats * 0.4)))
    order = df_cat_b[col].value_counts().index
    ax = sns.countplot(data=df_cat_b, y=col, order=order, palette="viridis")
    
    for p in ax.patches:
        width = p.get_width()
        y_pos = p.get_y() + p.get_height() / 2.

        ax.annotate(
            f'{int(width)}', 
            (width, y_pos),             # Współrzędne (x, y)
            ha='left',                  # Wyrównanie do lewej (tekst za słupkiem)
            va='center',                # Wyśrodkowanie w pionie
            xytext=(5, 0),              # Przesunięcie o 5 pikseli w prawo od końca słupka
            textcoords='offset points',
            fontsize=10,
            fontweight='bold'
        )
    
    plt.title(f"Liczebność kategorii: {col}")
    plt.tight_layout()
    plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x1000 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x600 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x640 with 1 Axes>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_box_cathegories():
    plt.figure(figsize=(12, 15)) 

    for col in df_cat_b:
        sns.boxplot(
            data=df, 
            x='SalePrice', 
            y=col,
            palette='coolwarm'
        )
        
        plt.title("boxplot z kategorii " + col +  " dla SalePrice", fontsize=16)
        plt.grid(axis='x', linestyle='--', alpha=0.7)
        plt.show()

plot_box_cathegories()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x1500 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
df = df.sort_index(axis=1)
for col in df:
    print(col + ": " + str(df[col].dtype))
# Out:
# 1stFlrSF: int64
# 2ndFlrSF: int64
# 3SsnPorch: int64
# Alley: object
# BedroomAbvGr: int64
# BldgType: object
# BsmtCond: object
# BsmtExposure: object
# BsmtFinSF1: int64
# BsmtFinSF2: int64
# BsmtFinType1: object
# BsmtFinType2: object
# BsmtFullBath: int64
# BsmtHalfBath: int64
# BsmtQual: object
# BsmtUnfSF: int64
# CentralAir: object
# Condition1: object
# Condition2: object
# Electrical: object
# EnclosedPorch: int64
# ExterCond: object
# ExterQual: object
# Exterior1st: object
# Exterior2nd: object
# Fence: object
# FireplaceQu: object
# Fireplaces: int64
# Foundation: object
# FullBath: int64
# Functional: object
# GarageArea: int64
# GarageCars: int64
# GarageCond: object
# GarageFinish: object
# GarageQual: object
# GarageType: object
# GarageYrBlt: float64
# GrLivArea: int64
# HalfBath: int64
# Heating: object
# HeatingQC: object
# HouseStyle: object
# Id: int64
# KitchenAbvGr: int64
# KitchenQual: object
# LandContour: object
# LandSlope: object
# LotArea: int64
# LotConfig: object
# LotFrontage: float64
# LotShape: object
# LowQualFinSF: int64
# MSSubClass: int64
# MSZoning: object
# MasVnrArea: float64
# MasVnrType: object
# MiscFeature: object
# MiscVal: int64
# MoSold: int64
# Neighborhood: object
# OpenPorchSF: int64
# OverallCond: int64
# OverallQual: int64
# PavedDrive: object
# PoolArea: int64
# PoolQC: object
# RoofMatl: object
# RoofStyle: object
# SaleCondition: object
# SalePrice: int64
# SaleType: object
# ScreenPorch: int64
# Street: object
# TotRmsAbvGrd: int64
# TotalBsmtSF: int64
# Utilities: object
# WoodDeckSF: int64
# YearBuilt: int64
# YearRemodAdd: int64
# YrSold: int64

# %%
num_features
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'Id',
#     'MSSubClass',
#     'LotFrontage',
#     'LotArea',
#     'OverallQual',
#     'OverallCond',
#     'YearBuilt',
#     'YearRemodAdd',
#     'MasVnrArea',
#     'BsmtFinSF1',
#     'BsmtFinSF2',
#     'BsmtUnfSF',
#     'TotalBsmtSF',
#     '1stFlrSF',
#     '2ndFlrSF',
#     'LowQualFinSF',
#     'GrLivArea',
#     'BsmtFullBath',
#     'BsmtHalfBath',
#     'FullBath',
#     'HalfBath',
#     'BedroomAbvGr',
#     'KitchenAbvGr',
#     'TotRmsAbvGrd',
#     'Fireplaces',
#     'GarageYrBlt',
#     'GarageCars',
#     'GarageArea',
#     'WoodDeckSF',
#     'OpenPorchSF',
#     'EnclosedPorch',
#     '3SsnPorch',
#     'ScreenPorch',
#     'PoolArea',
#     'MiscVal',
#     'MoSold',
#     'YrSold',
#     'SalePrice'
# ]
