# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
# !uv pip install --upgrade seaborn matplotlib
# Out:
# Using Python 3.12.7 environment at: C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv
# Resolved 14 packages in 207ms
# Prepared 2 packages in 2ms
# Uninstalled 2 packages in 496ms
# Installed 2 packages in 945ms
#  - pandas==2.3.3
#  + pandas==3.0.1
#  - seaborn==0.12.2
#  + seaborn==0.13.2

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = catalog.load("all_experiments_results")
df
# Out:
# [03/26/26 11:55:49] INFO     Loading data from all_experiments_results (CSVDataset)...         ]8;id=360643;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=375980;file://C:\Users\arczi\source\repos\Mini\Msi\wsi-reg-cls\wsi-reg\.venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         1.098530      0.027907         0.102493        0.003386
# 1         1.084986      0.030726         0.101292        0.003316
# 2         1.087388      0.019762         0.101293        0.003431
# 3         0.857580      0.037500         0.104696        0.007612
# 4         0.895214      0.049629         0.097087        0.001675
# ...
